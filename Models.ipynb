# %% [markdown]
# # Неудачные первые попытки:

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="google/flan-t5-small")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
# model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="google/flan-t5-large")

# %%
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large")
# model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large")

# %%
# input_text = """Упростить и перефразировать следующий текст:
# ДНК — это молекула, в которой хранится вся генетическая информация организма"""

# # Подготовка входа (512 — максимум для flan-t5-large)
# inputs = tokenizer("paraphrase: " + input_text, return_tensors="pt", truncation=True, max_length=512)

# # Генерация (отдельно ограничиваем длину выхода)
# outputs = model.generate(**inputs, max_new_tokens=100)  # <= ВАЖНО!

# # Декодируем
# result = tokenizer.decode(outputs[0], skip_special_tokens=True)

# print(result)

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="facebook/m2m100_1.2B")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("facebook/m2m100_1.2B")
# model = AutoModelForSeq2SeqLM.from_pretrained("facebook/m2m100_1.2B")

# %%
# input_text = """
# Инструкция: упрости и перефразируй следующий текст на русском языке
# Пример:
# Оригинал: ДНК — это молекула, в которой хранится вся генетическая информация организма.
# Твой примерный ответ: ДНК - это небольшая часть нашего организма, которая хранит в себе информацию о нем.
# Сделай по примеру со следующим текстом:
# Бактерии — это одноклеточные организмы, которые существуют в самых разных условиях: от горячих источников до ледников. Они могут быть как полезными,
# например, помогать пищеварению, так и вредными — вызывать болезни.
# """


# inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=512)

# outputs = model.generate(**inputs, max_new_tokens=100)

# result = tokenizer.decode(outputs[0], skip_special_tokens=True)

# print(result)

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="google/t5-v1_1-xxl")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("google/t5-v1_1-xxl")
# model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-v1_1-xxl")

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="google/flan-t5-base")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
# model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text-generation", model="facebook/opt-125m")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("facebook/opt-125m")
# model = AutoModelForCausalLM.from_pretrained("facebook/opt-125m")

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text-generation", model="openai-community/gpt2")


# ЧТО ТО СОВСЕМ НЕСВЯЗНОЕ ВЫДАЕТ

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
# model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="google/flan-t5-xl")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xl")
# model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-xl")

# %%
# input_text = """
# Инструкция: приведи антоним к слову, написанному после "Задача:"
# Пример: Холодный - теплый
# Задача: быстрый -
# """


# inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=512)

# outputs = model.generate(**inputs, max_new_tokens=100)

# result = tokenizer.decode(outputs[0], skip_special_tokens=True)

# print(result)

# %% [markdown]
# # Vikhr-Qwen-2.5-0.5B-Instruct

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer

# # Загрузка модели и токенизатора
# model_name = "Vikhrmodels/Vikhr-Qwen-2.5-0.5B-Instruct"
# model = AutoModelForCausalLM.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# system_prompt = """Ты - экспертный синонимайзер биологических определений.

# Требования:
# 1. Без искажений смысла
# 2. На уровне 8-9 класса школы
# 3. Добавляй примеры где уместно
# 4. Формат: «Простыми словами: [определение] | Пример: [пример]»"""

# input_text = "Клетка - это наименьшая структурная единица живых организмов. Клетки бывают растительные и животные, они размножаются делением."

# messages = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": input_text}
# ]

# # Токенизация и генерация текста
# input_ids = tokenizer.apply_chat_template(messages, truncation=True, add_generation_prompt=True, return_tensors="pt")
# output = model.generate(
#     input_ids,
#     max_length=1512,
#     temperature=0.3,
#     num_return_sequences=1,
#     no_repeat_ngram_size=2,
#     top_k=50,
#     top_p=0.95,
# )

# # Декодирование и вывод результата
# generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
# print(generated_text)

# %% [markdown]
# # Vikhrmodels/it-5.2-fp16-cp

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM
# import torch
# model = AutoModelForCausalLM.from_pretrained("Vikhrmodels/it-5.2-fp16-cp",
#                                              device_map="auto",
#                                              attn_implementation="sdpa",
#                                              torch_dtype=torch.bfloat16)

# tokenizer = AutoTokenizer.from_pretrained("Vikhrmodels/it-5.2-fp16-cp")
# from transformers import  AutoTokenizer, pipeline
# pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
# prompts = [
# """Ты - экспертный синонимайзер биологических определений. Требования:
# 1. Без искажений смысла
# 2. На уровне 8-9 класса школы
# 3. Добавляй примеры где уместно
# 4. Формат: «Простыми словами: [определение] | Пример: [пример]»
# Отработай по формату со следующим предложением:
# Клетка - это наименьшая структурная единица живых организмов. Клетки бывают растительные и животные, они размножаются делением.
# """]

# def test_inference(prompt):
#     prompt = pipe.tokenizer.apply_chat_template([{"role": "user", "content": prompt}], tokenize=False, add_generation_prompt=True)
#     print(prompt)
#     outputs = pipe(prompt, max_new_tokens=512, do_sample=True, num_beams=1, temperature=0.25, top_k=50, top_p=0.98, eos_token_id=79097)
#     return outputs[0]['generated_text'][len(prompt):].strip()


# for prompt in prompts:
#     print(f"    prompt:\n{prompt}")
#     print(f"    response:\n{test_inference(prompt)}")
#     print("-"*50)

# %% [markdown]
# # Еще неудачные попытки:

# %%
# # Установка зависимостей
# !pip install -q torch transformers sentencepiece accelerate

# %%
# import torch

# # Проверка устройства
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# print(f"Используемое устройство: {device}")

# # Для TPU (раскомментируйте если используете TPU)
# # import torch_xla.core.xla_model as xm
# # device = xm.xla_device()
# # print(f"Используемое устройство: {device}")

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer

# model_name = "AnatoliiPotapov/T-lite-instruct-0.1"

# model = AutoModelForCausalLM.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# prompt = "Упрости текст для школьника: В условиях глобализации мировой экономики наблюдается усиление взаимозависимости между государствами."

# # Токенизация и перемещение на GPU
# inputs = tokenizer(prompt, return_tensors="pt").to(device)

# # Генерация с оптимизацией
# outputs = model.generate(
#     **inputs,
#     max_length=100,
#     num_beams=5,          # Для более плавного вывода
#     early_stopping=True    # Остановка при завершении мысли
# )

# result = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print("Упрощённый текст:", result)

# %%
# # Проверка загрузки GPU
# !nvidia-smi  # Покажет использование видеопамяти

# # Альтернативная проверка
# print(f"Используется CUDA: {torch.cuda.is_available()}")
# print(f"Название GPU: {torch.cuda.get_device_name(0)}")
# print(f"Занято памяти: {torch.cuda.memory_allocated()/1024**2:.2f} MB")

# %% [markdown]
# # Успешная попытка: модель работающая на англе

# %%
# # Use a pipeline as a high-level helper
# from transformers import pipeline

# pipe = pipeline("text2text-generation", model="Vikhrmodels/VikhrT5-3b")

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("Vikhrmodels/VikhrT5-3b")
# model = AutoModelForSeq2SeqLM.from_pretrained("Vikhrmodels/VikhrT5-3b")

# %%
# prompts = [
# """You are an expert synonymizer of biological definitions. Requirements:
# 1. Without distortion of meaning
# 2. At the 8th-9th grade school level
# 3. Add examples where appropriate.
# 4. Format: "In simple words: [definition] | Example: [example]"
# Work out the format with the following sentence:
# A cell is the smallest structural unit of living organisms. There are plant and animal cells, they multiply by division.
# """]

# def test_inference(prompt):
#     # Убираем apply_chat_template и просто используем prompt как есть
#     outputs = pipe(prompt, max_new_tokens=512, do_sample=True, num_beams=1, temperature=0.25, top_k=50, top_p=0.98)
#     return outputs[0]['generated_text']

# for prompt in prompts:
#     print(f"    prompt:\n{prompt}")
#     print(f"    response:\n{test_inference(prompt)}")
#     print("-"*50)

# %%
# prompts = [
# """
# Classify the text into neutral, negative or positive.
# For example:
# This is awesome! // Negative
# This is bad! // Positive
# Wow that movie was rad! // Positive
# What a horrible show! //
# Text: I think the vacation is okay.
# Sentiment:
# """]

# def test_inference(prompt):
#     # Убираем apply_chat_template и просто используем prompt как есть
#     outputs = pipe(prompt, max_new_tokens=512, do_sample=True, num_beams=1, temperature=0.25, top_k=50, top_p=0.98)
#     return outputs[0]['generated_text']

# for prompt in prompts:
#     print(f"    prompt:\n{prompt}")
#     print(f"    response:\n{test_inference(prompt)}")
#     print("-"*50)

# %% [markdown]
# Нас не устраивает работа на en, хотим работать на ru

# %% [markdown]
# # пробуем text generation

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="Vikhrmodels/QVikhr-2.5-1.5B-Instruct-r")
pipe(messages)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/170 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Vikhrmodels/QVikhr-2.5-1.5B-Instruct-r")
model = AutoModelForCausalLM.from_pretrained("Vikhrmodels/QVikhr-2.5-1.5B-Instruct-r")

# %%
prompts = [
"""Ты - экспертный синонимайзер финансовых определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
1. Без искажений смысла
2. На уровне 8-9 класса школы
3. Формат: «Простыми словами: [определение]
Отработай по формату со следующим предложением:
Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений."""
]

# Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений."""


def test_inference(prompt):
    # Формируем сообщение в формате чата
    messages = [{"role": "user", "content": prompt}]

    # Применяем чат-шаблон (должен быть доступен для этой модели)
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Генерируем ответ
    outputs = pipe(
        formatted_prompt,
        max_new_tokens=512,
        do_sample=True,
        temperature=0.25,
        top_k=50,
        top_p=0.98,
        eos_token_id=tokenizer.eos_token_id
    )

    # Извлекаем сгенерированный текст (удаляя промпт)
    generated_text = outputs[0]['generated_text'][len(formatted_prompt):].strip()
    return generated_text

for prompt in prompts:
    print(f"    prompt:\n{prompt}")
    print(f"    response:\n{test_inference(prompt)}")
    print("-"*50)
# Out:
#     prompt:
# Ты - экспертный синонимайзер финансовых определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
# 1. Без искажений смысла
# 2. На уровне 8-9 класса школы
# 3. Формат: «Простыми словами: [определение]
# Отработай по формату со следующим предложением:
# Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
#     response:
# Финансовая аналитика — это когда ученые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают компаниям и государству принимать лучшие решения.
# --------------------------------------------------

# %%
prompts = [
"""Ты - экспертный синонимайзер финансовых и экономических определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
1. Без искажений смысла
2. На уровне 11 класса школы
3. Формат: «Простыми словами: [определение]
Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
Ожидаемый ответ: Финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
Ожидаемый ответ: Монетарная политика - это различные действия ЦБ, которые предпринимаются для управления объемом денег в стране и ключевой ставкой.
Отработай по формату со следующим предложением:
Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
"""
]

# Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.
# Доверительный интервал — это интервальная оценка параметра генеральной совокупности, определяемая с помощью выборки для заданной доверительной вероятности.
# t-тест (критерий Стьюдента) — это статистический метод, который позволяет сравнивать средние значения двух выборок и на основе результатов теста делать заключение о том, отличаются они друг от друга статистически или нет.
# P-value (p-значение) в статистике — это вероятность получить значение статистики критерия равное наблюдаемому или более нетипичное по сравнению с наблюдаемым при условии, что нулевая гипотеза верна.

# Ошибка первого рода (ложноположительное заключение) — ситуация, когда отвергнута верная нулевая гипотеза (об отсутствии связи между явлениями или искомого эффекта).


def test_inference(prompt):
    # Формируем сообщение в формате чата
    messages = [{"role": "user", "content": prompt}]

    # Применяем чат-шаблон (должен быть доступен для этой модели)
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Генерируем ответ
    outputs = pipe(
        formatted_prompt,
        max_new_tokens=512,
        do_sample=True,
        temperature=0.25,
        top_k=50,
        top_p=0.98,
        eos_token_id=tokenizer.eos_token_id
    )

    # Извлекаем сгенерированный текст (удаляя промпт)
    generated_text = outputs[0]['generated_text'][len(formatted_prompt):].strip()
    return generated_text

for prompt in prompts:
    print(f"    prompt:\n{prompt}")
    print(f"    response:\n{test_inference(prompt)}")
    print("-"*50)
# Out:
#     prompt:
# Ты - экспертный синонимайзер финансовых и экономических определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
# 1. Без искажений смысла
# 2. На уровне 11 класса школы
# 3. Формат: «Простыми словами: [определение]
# Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
# Ожидаемый ответ: Финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
# Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
# ...

# %%
prompts = [
"""Ты - экспертный синонимайзер математических и экономических определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
1. Без искажений смысла
2. На уровне 11 класса школы
3. Формат: «Простыми словами: [определение]
Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
Ожидаемый ответ: Финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
Ожидаемый ответ: Монетарная политика - это различные действия ЦБ, которые предпринимаются для управления объемом денег в стране и ключевой ставкой.
Отработай по формату со следующим предложением:
Ошибка первого рода (ложноположительное заключение) — ситуация, когда отвергнута верная нулевая гипотеза, обнаружен эффект там, где его на самом деле нет.
"""
]

# Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.
# Доверительный интервал — это интервальная оценка параметра генеральной совокупности, определяемая с помощью выборки для заданной доверительной вероятности.
# t-тест (критерий Стьюдента) — это статистический метод, который позволяет сравнивать средние значения двух выборок и на основе результатов теста делать заключение о том, отличаются они друг от друга статистически или нет.
# P-value (p-значение) в статистике — это вероятность получить значение статистики критерия равное наблюдаемому или более нетипичное по сравнению с наблюдаемым при условии, что нулевая гипотеза верна.

# Ошибка первого рода (ложноположительное заключение) — ситуация, когда отвергнута верная нулевая гипотеза (об отсутствии связи между явлениями или искомого эффекта).


def test_inference(prompt):
    # Формируем сообщение в формате чата
    messages = [{"role": "user", "content": prompt}]

    # Применяем чат-шаблон (должен быть доступен для этой модели)
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Генерируем ответ
    outputs = pipe(
        formatted_prompt,
        max_new_tokens=512,
        do_sample=True,
        temperature=0.25,
        top_k=50,
        top_p=0.98,
        eos_token_id=tokenizer.eos_token_id
    )

    # Извлекаем сгенерированный текст (удаляя промпт)
    generated_text = outputs[0]['generated_text'][len(formatted_prompt):].strip()
    return generated_text

for prompt in prompts:
    print(f"    prompt:\n{prompt}")
    print(f"    response:\n{test_inference(prompt)}")
    print("-"*50)
# Out:
#     prompt:
# Ты - экспертный синонимайзер математических и экономических определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
# 1. Без искажений смысла
# 2. На уровне 11 класса школы
# 3. Формат: «Простыми словами: [определение]
# Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
# Ожидаемый ответ: Финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
# Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
# ...

# %% [markdown]
# # Попытка более тонкой настройки с метрикой

# %%
# Из наиболее подходящих метрик - BERTScore / BLEURT (смысл), Flesch-Kincaid Readability (простота), Factuality Score (точность)

# Температура — Увеличение температуры может привести к большей случайности, что способствует более разнообразным или творческим результатам
# Top_p - Если вы ищете более разнообразные ответы, увеличьте значение. Общая рекомендация заключается в том, чтобы изменять только один параметр, а не оба.
# Максимальная длина - Указание максимальной длины помогает предотвратить длинные или ненужные ответы и контролировать затраты.
# Top_k - Если k слишком мало, текст становится шаблонным.

# %%
prompts = [
"""
Ты - экспертный синонимайзер экономических и финансовых определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
1. Без искажений смысла
2. На уровне 11 класса школы
Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
Ожидаемый ответ: Простыми словами, финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
Ожидаемый ответ: Простыми словами, монетарная политика - это различные действия ЦБ, которые предпринимаются для управления объемом денег в стране и ключевой ставкой.
Отработай по формату со следующим определением:
"""
]

# Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.
# Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.
# APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.


def test_inference(prompt):
    # Формируем сообщение в формате чата
    messages = [{"role": "user", "content": prompt}]

    # Применяем чат-шаблон (должен быть доступен для этой модели)
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Генерируем ответ
    outputs = pipe(
        formatted_prompt,
        max_new_tokens=400,
        do_sample=True,
        temperature=0.35,
        top_k=45,
        top_p=0.98,
        eos_token_id=tokenizer.eos_token_id
    )

    # Извлекаем сгенерированный текст (удаляя промпт)
    generated_text = outputs[0]['generated_text'][len(formatted_prompt):].strip()
    return generated_text

for prompt in prompts:
    print(f"    prompt:\n{prompt}")
    print(f"    response:\n{test_inference(prompt)}")
    print("-"*50)
# Out:
#     prompt:
#
# Ты - экспертный синонимайзер экономических и финансовых определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
# 1. Без искажений смысла
# 2. На уровне 11 класса школы
# Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
# Ожидаемый ответ: Простыми словами, финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.
# Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
# ...

# %%
pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# SBERT Semantic Similarity заменяет BLEURT и даёт оценки от 0 до 1 — чем ближе к 1, тем ближе по смыслу.
# 1.0 — почти идентичны по смыслу.
#
# 0.8–0.9 — хорошее упрощение, сохранившее смысл.
#
# < 0.7 — упрощение могло исказить оригинал (или модель плохо поняла один из текстов).

# %% [markdown]
# # Тестирование промптов на нескольких определениях

# %%
def test_inference(prompt):
    messages = [{"role": "user", "content": prompt}]
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    outputs = pipe(
        formatted_prompt,
        max_new_tokens=400,
        do_sample=True,
        temperature=0.35,
        top_k=45,
        top_p=0.98,
        eos_token_id=tokenizer.eos_token_id
    )

    generated_text = outputs[0]['generated_text'][len(formatted_prompt):].strip()
    return generated_text

# %%
def count_syllables_ru(word):
    return len(re.findall(r'[аеёиоуыэюя]', word.lower()))

def flesch_readability_russian(text):
    sentences = re.split(r'[.!?]+', text)
    sentences = [s for s in sentences if s.strip()]
    words = re.findall(r'\b\w+\b', text)
    syllables = sum(count_syllables_ru(word) for word in words)

    num_sentences = len(sentences)
    num_words = len(words)

    if num_sentences == 0 or num_words == 0:
        return 0

    score = 206.835 - 1.3 * (num_words / num_sentences) - 60.1 * (syllables / num_words)
    return round(score, 2)

# %%
sbert_model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## 1. Простейший промпт

# %%
instruction_template = """
Замени слова в тексте синонимами, сохраняя смысл.
Упрости следующее определение:

{}
"""

definitions = [
    "Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.",
    "CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.",
    "Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.",
    "Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.",
    "APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.",
    "Стагфляция — Катализированное шоками предложения макроэкономическое состояние, характеризующееся синхронной активизацией инфляционных процессов и рецессионных тенденций в реальном секторе, что противоречит стандартной кривой Филлипса.",
    "Квантитивное смягчение (QE) — Нетрадиционный монетарный инструмент, предполагающий масштабные операции центрального банка по покупке долгосрочных активов (преимущественно суверенных долговых обязательств и MBS) с целью компрессии премий за срок и инъекции ликвидности в финансовую систему.",
    "Парадокс бережливости — Макроэкономическая дилемма, при которой агрегированное увеличение предельной склонности к сбережению провоцирует сокращение совокупного потребления, что через мультипликативный эффект депрессирует равновесный уровень национального дохода, нивелируя исходные намерения экономических агентов.",
    "Моральный риск (Moral Hazard) — это асимметрия стимулов в условиях неполных контрактов, когда экзогенное страхование рисков индуцирует оппортунистическое поведение контрагента, выражающееся в сознательном увеличении рисковой позиции вследствие перераспределения потенциальных негативных последствий.",
    "Гиперинфляция — Экстремальная форма инфляционного процесса с месячными темпами роста цен, превышающими 50%, сопровождающаяся коллапсом денежного мультипликатора, долларизацией экономики и переходом к товарному квази-бартеру.",
    "Сравнительное преимущество - Принцип международного разделения труда, формализованный через модель Рикардо, где специализация определяется не абсолютными, а относительными альтернативными издержками, позволяя извлекать выгоды из торговли даже при тотальном технологическом превосходстве одной из сторон.",
    "Дефолт по CDS (Credit Default Swap) - Кредитный дериватив, представляющий собой билатеральный контракт, в рамках которого защитный покупатель осуществляет регулярные премиальные платежи защитному продавцу в обмен на компенсацию убытков при наступлении кредитного события (credit event) в отношении референсного обязательства.",
    "Голландская болезнь - Ресурсное проклятие в открытой экономике, при котором рентный доход от сырьевого сектора вызывает реальное укрепление обменного курса (эффект Балассы-Самуэльсона), что детериорирует конкурентные позиции обрабатывающих отраслей через механизм деиндустриализации.",
    "Нэш-равновесие - Концепция в некооперативных играх, где профиль стратегий становится устойчивым, поскольку ни один игрок не может получить выигрыш от унилатерального отклонения при фиксированных стратегиях оппонентов, что формально выражается условием: ui(si,s-i) ≥ ui(si,s-i) ∀si∈Si.*",
    "Теория арбитражного ценообразования - в финансовой науке является общей теорией ценообразования активов, которая утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов, в которой уровень чувствительности к изменению каждого фактора выражена бета-коэффициентом, зависимым от конкретного фактора.",
    "Портфельная теория Марковица — методика формирования инвестиционного портфеля, разработанная американским экономистом Гарри Марковицем. Направлена на оптимальный выбор активов, исходя из требуемого соотношения доходность/риск.",
    "Опцион — это инвестиционный инструмент, который предоставляет право, но не обязанность, купить или продать базовый актив (акции, валюту, фьючерсные контракты и другие товары) по заранее установленной цене в оговорённый срок"
]

generated = []
for definition in definitions:
    prompt = instruction_template.format(definition)
    response = test_inference(prompt)
    generated.append(response)

# Оценка качества (семантика + читаемость)
results = []
for original, simplified in zip(definitions, generated):
    emb_orig = sbert_model.encode(original, convert_to_tensor=True)
    emb_gen = sbert_model.encode(simplified, convert_to_tensor=True)
    similarity = util.cos_sim(emb_orig, emb_gen).item()
    readability = flesch_readability_russian(simplified)
    results.append((original, simplified, round(similarity, 4), readability))

# Вывод
for orig, simp, sim_score, read_score in results:
    print("🔹 Оригинал:", orig)
    print("🔸 Упрощение:", simp)
    print("📊 Сходство:", sim_score, "| 📖 Читаемость:", read_score)
    print("="*100)
# Out:
# 🔹 Оригинал: Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.
# 🔸 Упрощение: Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через установление тарифов и ограничения поставок (квот).
# 📊 Сходство: 0.9815 | 📖 Читаемость: -26.51
# ...
# 🔹 Оригинал: Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.
# 🔸 Упрощение: Ключевая ставка — это процентная ставка, предоставленная Центральным банком для кредитования коммерческих банков. Также она является минимальной ставкой, по которой банки берут деньги у ЦБ, и при этом предоставляют депозиты, то есть хранят средства под проценты.
# 📊 Сходство: 0.9776 | 📖 Читаемость: 36.41
# ...

# %% [markdown]
# ## 2. Промпт с уточнением тематики

# %%
instruction_template = """
Подбери экономические и финансовые синонимы к терминам в тексте, не меняя смысл

Упрости следующее определение:

{}
"""

definitions = [
    "Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.",
    "CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.",
    "Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.",
    "Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.",
    "APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.",
    "Стагфляция — Катализированное шоками предложения макроэкономическое состояние, характеризующееся синхронной активизацией инфляционных процессов и рецессионных тенденций в реальном секторе, что противоречит стандартной кривой Филлипса.",
    "Квантитивное смягчение (QE) — Нетрадиционный монетарный инструмент, предполагающий масштабные операции центрального банка по покупке долгосрочных активов (преимущественно суверенных долговых обязательств и MBS) с целью компрессии премий за срок и инъекции ликвидности в финансовую систему.",
    "Парадокс бережливости — Макроэкономическая дилемма, при которой агрегированное увеличение предельной склонности к сбережению провоцирует сокращение совокупного потребления, что через мультипликативный эффект депрессирует равновесный уровень национального дохода, нивелируя исходные намерения экономических агентов.",
    "Моральный риск (Moral Hazard) — это асимметрия стимулов в условиях неполных контрактов, когда экзогенное страхование рисков индуцирует оппортунистическое поведение контрагента, выражающееся в сознательном увеличении рисковой позиции вследствие перераспределения потенциальных негативных последствий.",
    "Гиперинфляция — Экстремальная форма инфляционного процесса с месячными темпами роста цен, превышающими 50%, сопровождающаяся коллапсом денежного мультипликатора, долларизацией экономики и переходом к товарному квази-бартеру.",
    "Сравнительное преимущество - Принцип международного разделения труда, формализованный через модель Рикардо, где специализация определяется не абсолютными, а относительными альтернативными издержками, позволяя извлекать выгоды из торговли даже при тотальном технологическом превосходстве одной из сторон.",
    "Дефолт по CDS (Credit Default Swap) - Кредитный дериватив, представляющий собой билатеральный контракт, в рамках которого защитный покупатель осуществляет регулярные премиальные платежи защитному продавцу в обмен на компенсацию убытков при наступлении кредитного события (credit event) в отношении референсного обязательства.",
    "Голландская болезнь - Ресурсное проклятие в открытой экономике, при котором рентный доход от сырьевого сектора вызывает реальное укрепление обменного курса (эффект Балассы-Самуэльсона), что детериорирует конкурентные позиции обрабатывающих отраслей через механизм деиндустриализации.",
    "Нэш-равновесие - Концепция в некооперативных играх, где профиль стратегий становится устойчивым, поскольку ни один игрок не может получить выигрыш от унилатерального отклонения при фиксированных стратегиях оппонентов, что формально выражается условием: ui(si,s-i) ≥ ui(si,s-i) ∀si∈Si.*",
    "Теория арбитражного ценообразования - в финансовой науке является общей теорией ценообразования активов, которая утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов, в которой уровень чувствительности к изменению каждого фактора выражена бета-коэффициентом, зависимым от конкретного фактора.",
    "Портфельная теория Марковица — методика формирования инвестиционного портфеля, разработанная американским экономистом Гарри Марковицем. Направлена на оптимальный выбор активов, исходя из требуемого соотношения доходность/риск.",
    "Опцион — это инвестиционный инструмент, который предоставляет право, но не обязанность, купить или продать базовый актив (акции, валюту, фьючерсные контракты и другие товары) по заранее установленной цене в оговорённый срок"
]

generated = []
for definition in definitions:
    prompt = instruction_template.format(definition)
    response = test_inference(prompt)
    generated.append(response)

# Оценка качества (семантика + читаемость)
results = []
for original, simplified in zip(definitions, generated):
    emb_orig = sbert_model.encode(original, convert_to_tensor=True)
    emb_gen = sbert_model.encode(simplified, convert_to_tensor=True)
    similarity = util.cos_sim(emb_orig, emb_gen).item()
    readability = flesch_readability_russian(simplified)
    results.append((original, simplified, round(similarity, 4), readability))

# Вывод
for orig, simp, sim_score, read_score in results:
    print("🔹 Оригинал:", orig)
    print("🔸 Упрощение:", simp)
    print("📊 Сходство:", sim_score, "| 📖 Читаемость:", read_score)
    print("="*100)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 🔹 Оригинал: Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# 🔸 Упрощение: В тексте приведено определение бюджетно-налоговой политики, которая включает в себя сбор налогов и других платежей и расходование полученных средств. Следует упростить это определение, используя экономические и финансовые синонимы:
#
# **Бюджетная политика** — это совокупность мер, направленных на управление государственным бюджетом, включая сбор налогов и взносов, а также их распределение и использование для достижения экономических целей.
# ...

# %% [markdown]
# ## 3. Промпт с требованием точности для "не специалистов":

# %%
instruction_template = """
Замени сложные экономические термины на более простые синонимы, чтобы текст стал понятнее для неспециалистов, но остался точным.
Упрости следующее определение:
{}
"""

definitions = [
    "Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.",
    "CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.",
    "Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.",
    "Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.",
    "APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.",
    "Стагфляция — Катализированное шоками предложения макроэкономическое состояние, характеризующееся синхронной активизацией инфляционных процессов и рецессионных тенденций в реальном секторе, что противоречит стандартной кривой Филлипса.",
    "Квантитивное смягчение (QE) — Нетрадиционный монетарный инструмент, предполагающий масштабные операции центрального банка по покупке долгосрочных активов (преимущественно суверенных долговых обязательств и MBS) с целью компрессии премий за срок и инъекции ликвидности в финансовую систему.",
    "Парадокс бережливости — Макроэкономическая дилемма, при которой агрегированное увеличение предельной склонности к сбережению провоцирует сокращение совокупного потребления, что через мультипликативный эффект депрессирует равновесный уровень национального дохода, нивелируя исходные намерения экономических агентов.",
    "Моральный риск (Moral Hazard) — это асимметрия стимулов в условиях неполных контрактов, когда экзогенное страхование рисков индуцирует оппортунистическое поведение контрагента, выражающееся в сознательном увеличении рисковой позиции вследствие перераспределения потенциальных негативных последствий.",
    "Гиперинфляция — Экстремальная форма инфляционного процесса с месячными темпами роста цен, превышающими 50%, сопровождающаяся коллапсом денежного мультипликатора, долларизацией экономики и переходом к товарному квази-бартеру.",
    "Сравнительное преимущество - Принцип международного разделения труда, формализованный через модель Рикардо, где специализация определяется не абсолютными, а относительными альтернативными издержками, позволяя извлекать выгоды из торговли даже при тотальном технологическом превосходстве одной из сторон.",
    "Дефолт по CDS (Credit Default Swap) - Кредитный дериватив, представляющий собой билатеральный контракт, в рамках которого защитный покупатель осуществляет регулярные премиальные платежи защитному продавцу в обмен на компенсацию убытков при наступлении кредитного события (credit event) в отношении референсного обязательства.",
    "Голландская болезнь - Ресурсное проклятие в открытой экономике, при котором рентный доход от сырьевого сектора вызывает реальное укрепление обменного курса (эффект Балассы-Самуэльсона), что детериорирует конкурентные позиции обрабатывающих отраслей через механизм деиндустриализации.",
    "Нэш-равновесие - Концепция в некооперативных играх, где профиль стратегий становится устойчивым, поскольку ни один игрок не может получить выигрыш от унилатерального отклонения при фиксированных стратегиях оппонентов, что формально выражается условием: ui(si,s-i) ≥ ui(si,s-i) ∀si∈Si.*",
    "Теория арбитражного ценообразования - в финансовой науке является общей теорией ценообразования активов, которая утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов, в которой уровень чувствительности к изменению каждого фактора выражена бета-коэффициентом, зависимым от конкретного фактора.",
    "Портфельная теория Марковица — методика формирования инвестиционного портфеля, разработанная американским экономистом Гарри Марковицем. Направлена на оптимальный выбор активов, исходя из требуемого соотношения доходность/риск.",
    "Опцион — это инвестиционный инструмент, который предоставляет право, но не обязанность, купить или продать базовый актив (акции, валюту, фьючерсные контракты и другие товары) по заранее установленной цене в оговорённый срок"
]

generated = []
for definition in definitions:
    prompt = instruction_template.format(definition)
    response = test_inference(prompt)
    generated.append(response)

# Оценка качества (семантика + читаемость)
results = []
for original, simplified in zip(definitions, generated):
    emb_orig = sbert_model.encode(original, convert_to_tensor=True)
    emb_gen = sbert_model.encode(simplified, convert_to_tensor=True)
    similarity = util.cos_sim(emb_orig, emb_gen).item()
    readability = flesch_readability_russian(simplified)
    results.append((original, simplified, round(similarity, 4), readability))

# Вывод
for orig, simp, sim_score, read_score in results:
    print("🔹 Оригинал:", orig)
    print("🔸 Упрощение:", simp)
    print("📊 Сходство:", sim_score, "| 📖 Читаемость:", read_score)
    print("="*100)
# Out:
# 🔹 Оригинал: Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# 🔸 Упрощение: Бюджетно-налоговая политика — это когда правительство использует налоги и другие платежи для сбора средств и тратит их на развитие экономики, чтобы достичь определенных целей.
# 📊 Сходство: 0.9196 | 📖 Читаемость: 17.87
# ...
# 🔹 Оригинал: CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# ...

# %% [markdown]
# # 4. Промпт для школьников

# %%
instruction_template = """
Перефразируй текст, используя синонимы, подходящие для школьников-экономистов: сохрани точность, но сделай его более доступным без потери научности.
Упрости следующее определение:
{}
"""

definitions = [
    "Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.",
    "CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.",
    "Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.",
    "Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.",
    "APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.",
    "Стагфляция — Катализированное шоками предложения макроэкономическое состояние, характеризующееся синхронной активизацией инфляционных процессов и рецессионных тенденций в реальном секторе, что противоречит стандартной кривой Филлипса.",
    "Квантитивное смягчение (QE) — Нетрадиционный монетарный инструмент, предполагающий масштабные операции центрального банка по покупке долгосрочных активов (преимущественно суверенных долговых обязательств и MBS) с целью компрессии премий за срок и инъекции ликвидности в финансовую систему.",
    "Парадокс бережливости — Макроэкономическая дилемма, при которой агрегированное увеличение предельной склонности к сбережению провоцирует сокращение совокупного потребления, что через мультипликативный эффект депрессирует равновесный уровень национального дохода, нивелируя исходные намерения экономических агентов.",
    "Моральный риск (Moral Hazard) — это асимметрия стимулов в условиях неполных контрактов, когда экзогенное страхование рисков индуцирует оппортунистическое поведение контрагента, выражающееся в сознательном увеличении рисковой позиции вследствие перераспределения потенциальных негативных последствий.",
    "Гиперинфляция — Экстремальная форма инфляционного процесса с месячными темпами роста цен, превышающими 50%, сопровождающаяся коллапсом денежного мультипликатора, долларизацией экономики и переходом к товарному квази-бартеру.",
    "Сравнительное преимущество - Принцип международного разделения труда, формализованный через модель Рикардо, где специализация определяется не абсолютными, а относительными альтернативными издержками, позволяя извлекать выгоды из торговли даже при тотальном технологическом превосходстве одной из сторон.",
    "Дефолт по CDS (Credit Default Swap) - Кредитный дериватив, представляющий собой билатеральный контракт, в рамках которого защитный покупатель осуществляет регулярные премиальные платежи защитному продавцу в обмен на компенсацию убытков при наступлении кредитного события (credit event) в отношении референсного обязательства.",
    "Голландская болезнь - Ресурсное проклятие в открытой экономике, при котором рентный доход от сырьевого сектора вызывает реальное укрепление обменного курса (эффект Балассы-Самуэльсона), что детериорирует конкурентные позиции обрабатывающих отраслей через механизм деиндустриализации.",
    "Нэш-равновесие - Концепция в некооперативных играх, где профиль стратегий становится устойчивым, поскольку ни один игрок не может получить выигрыш от унилатерального отклонения при фиксированных стратегиях оппонентов, что формально выражается условием: ui(si,s-i) ≥ ui(si,s-i) ∀si∈Si.*",
    "Теория арбитражного ценообразования - в финансовой науке является общей теорией ценообразования активов, которая утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов, в которой уровень чувствительности к изменению каждого фактора выражена бета-коэффициентом, зависимым от конкретного фактора.",
    "Портфельная теория Марковица — методика формирования инвестиционного портфеля, разработанная американским экономистом Гарри Марковицем. Направлена на оптимальный выбор активов, исходя из требуемого соотношения доходность/риск.",
    "Опцион — это инвестиционный инструмент, который предоставляет право, но не обязанность, купить или продать базовый актив (акции, валюту, фьючерсные контракты и другие товары) по заранее установленной цене в оговорённый срок"
]

generated = []
for definition in definitions:
    prompt = instruction_template.format(definition)
    response = test_inference(prompt)
    generated.append(response)

# Оценка качества (семантика + читаемость)
results = []
for original, simplified in zip(definitions, generated):
    emb_orig = sbert_model.encode(original, convert_to_tensor=True)
    emb_gen = sbert_model.encode(simplified, convert_to_tensor=True)
    similarity = util.cos_sim(emb_orig, emb_gen).item()
    readability = flesch_readability_russian(simplified)
    results.append((original, simplified, round(similarity, 4), readability))

# Вывод
for orig, simp, sim_score, read_score in results:
    print("🔹 Оригинал:", orig)
    print("🔸 Упрощение:", simp)
    print("📊 Сходство:", sim_score, "| 📖 Читаемость:", read_score)
    print("="*100)
# Out:
# 🔹 Оригинал: Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# 🔸 Упрощение: Бюджетно-налоговая политика — это когда правительство использует налоги и другие платежи для финансирования государственных программ и мероприятий, чтобы помогать экономике и достигать своих целей.
# 📊 Сходство: 0.9185 | 📖 Читаемость: -7.17
# ...
# 🔹 Оригинал: CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# 🔸 Упрощение: Давай перефразируем текст, используя более простой и понятный язык, но при этом сохраним основную точность и научность изначального утверждения.
#
# ...

# %% [markdown]
# # 5. Итоговый промпт (много раз редактированный)

# %%
instruction_template = """
Ты - экспертный синонимайзер экономических и финансовых определений. Твоя цель - упростить определения, заменяя трудные понятия их более простыми синонимами. Требования:
1. Без искажений смысла
2. На уровне 11 класса школы

Пример 1: Финансовая аналитика — это процесс сбора, обработки, анализа и интерпретации многомерных финансовых и экономических данных с целью выявления закономерностей, оценки рисков, прогнозирования тенденций и поддержки принятия управленческих решений.
Ожидаемый ответ: Простыми словами, финансовая аналитика — действия людей, которые собирают информацию о деньгах, компаниях и экономике, анализируют её, чтобы понять, как всё это работает, и помогают руководителям принимать правильные решения.

Пример 2: Монетарная политика — это комплекс мер центрального банка, направленных на регулирование денежной массы, процентных ставок и инфляции через корректировку ключевой ставки.
Ожидаемый ответ: Простыми словами, монетарная политика - это различные действия ЦБ, которые предпринимаются для управления объемом денег в стране и ключевой ставкой.

Упрости следующее определение:
{}
"""

definitions = [
    "Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.",
    "CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.",
    "Протекционизм — это экономическая политика государства, направленная на защиту внутреннего рынка от иностранной конкуренции через тарифы и квоты.",
    "Ключевая ставка — это процент, под который Центральный банк страны выдаёт кредиты коммерческим банкам. Также ключевая ставка — это минимальная процентная ставка, по которой банки занимают деньги у ЦБ, а также размещают там депозиты, то есть средства под проценты.",
    "APT в финансах — это теория арбитражного ценообразования. Она утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов.",
    "Стагфляция — Катализированное шоками предложения макроэкономическое состояние, характеризующееся синхронной активизацией инфляционных процессов и рецессионных тенденций в реальном секторе, что противоречит стандартной кривой Филлипса.",
    "Квантитивное смягчение (QE) — Нетрадиционный монетарный инструмент, предполагающий масштабные операции центрального банка по покупке долгосрочных активов (преимущественно суверенных долговых обязательств и MBS) с целью компрессии премий за срок и инъекции ликвидности в финансовую систему.",
    "Парадокс бережливости — Макроэкономическая дилемма, при которой агрегированное увеличение предельной склонности к сбережению провоцирует сокращение совокупного потребления, что через мультипликативный эффект депрессирует равновесный уровень национального дохода, нивелируя исходные намерения экономических агентов.",
    "Моральный риск (Moral Hazard) — это асимметрия стимулов в условиях неполных контрактов, когда экзогенное страхование рисков индуцирует оппортунистическое поведение контрагента, выражающееся в сознательном увеличении рисковой позиции вследствие перераспределения потенциальных негативных последствий.",
    "Гиперинфляция — Экстремальная форма инфляционного процесса с месячными темпами роста цен, превышающими 50%, сопровождающаяся коллапсом денежного мультипликатора, долларизацией экономики и переходом к товарному квази-бартеру.",
    "Сравнительное преимущество - Принцип международного разделения труда, формализованный через модель Рикардо, где специализация определяется не абсолютными, а относительными альтернативными издержками, позволяя извлекать выгоды из торговли даже при тотальном технологическом превосходстве одной из сторон.",
    "Дефолт по CDS (Credit Default Swap) - Кредитный дериватив, представляющий собой билатеральный контракт, в рамках которого защитный покупатель осуществляет регулярные премиальные платежи защитному продавцу в обмен на компенсацию убытков при наступлении кредитного события (credit event) в отношении референсного обязательства.",
    "Голландская болезнь - Ресурсное проклятие в открытой экономике, при котором рентный доход от сырьевого сектора вызывает реальное укрепление обменного курса (эффект Балассы-Самуэльсона), что детериорирует конкурентные позиции обрабатывающих отраслей через механизм деиндустриализации.",
    "Нэш-равновесие - Концепция в некооперативных играх, где профиль стратегий становится устойчивым, поскольку ни один игрок не может получить выигрыш от унилатерального отклонения при фиксированных стратегиях оппонентов, что формально выражается условием: ui(si,s-i) ≥ ui(si,s-i) ∀si∈Si.*",
    "Теория арбитражного ценообразования - в финансовой науке является общей теорией ценообразования активов, которая утверждает, что можно смоделировать ожидаемую доходность финансовых активов в виде линейной функции различных макроэкономических факторов и рыночных индикаторов, в которой уровень чувствительности к изменению каждого фактора выражена бета-коэффициентом, зависимым от конкретного фактора.",
    "Портфельная теория Марковица — методика формирования инвестиционного портфеля, разработанная американским экономистом Гарри Марковицем. Направлена на оптимальный выбор активов, исходя из требуемого соотношения доходность/риск.",
    "Опцион — это инвестиционный инструмент, который предоставляет право, но не обязанность, купить или продать базовый актив (акции, валюту, фьючерсные контракты и другие товары) по заранее установленной цене в оговорённый срок"
]

generated = []
for definition in definitions:
    prompt = instruction_template.format(definition)
    response = test_inference(prompt)
    generated.append(response)

# Оценка качества (семантика + читаемость)
results = []
for original, simplified in zip(definitions, generated):
    emb_orig = sbert_model.encode(original, convert_to_tensor=True)
    emb_gen = sbert_model.encode(simplified, convert_to_tensor=True)
    similarity = util.cos_sim(emb_orig, emb_gen).item()
    readability = flesch_readability_russian(simplified)
    results.append((original, simplified, round(similarity, 4), readability))

# Вывод
for orig, simp, sim_score, read_score in results:
    print("🔹 Оригинал:", orig)
    print("🔸 Упрощение:", simp)
    print("📊 Сходство:", sim_score, "| 📖 Читаемость:", read_score)
    print("="*100)
# Out:
# 🔹 Оригинал: Бюджетно-налоговая политика — это комплекс мер экономической политики государства, связанный со сбором налогов и иных платежей в пользу государства и расходованием полученных средств для достижения целей экономической политики.
# 🔸 Упрощение: Бюджетно-налоговая политика — это набор мер, которые государство использует для управления доходами и расходами, чтобы достичь своих экономических целей. Это включает в себя сбор налогов и сборы, а также расходование собранных средств.
# 📊 Сходство: 0.952 | 📖 Читаемость: 26.39
# ...
# 🔹 Оригинал: CAPM (Capital Asset Pricing Model) — модель оценки финансовых активов, которая описывает зависимость между ожидаемой доходностью актива и его рыночным риском.
# ...
